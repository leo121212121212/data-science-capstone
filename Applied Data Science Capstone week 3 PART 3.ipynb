# %% [markdown]
# <H3>Hello, I will be using code comments instead of markdown cells</H3>
# <h4>have a nice day!</h4>

# %%
# import needed libs
import sys
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate

# %%
#get URL
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

#parse URL
soup = BeautifulSoup(website_url,'lxml')

#make html code pretty
soup.prettify()

#get table from code
My_table = soup.find('table',{'class':'wikitable sortable'})
df = pd.read_html(str(My_table))
df=df[0]

#naming the columns
df.columns = ['Postcode', 'Borough', 'Neighbourhood']

#dropping 1st row
df.drop(df.index[0], inplace=True)

#lets see what we got
print(df.head())
print(df.size)
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M1A      Not assigned      Not assigned
# 2      M2A      Not assigned      Not assigned
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront
# 867

# %%
#drop all rows containing "Not assigned" Neighbourhood
df.drop(df[df.Borough == 'Not assigned'].index, inplace=True)

#get rid of 'Not assigned Neighbourhoods
for index, row in df.iterrows():
    if row['Neighbourhood']=='Not assigned':
        row['Neighbourhood']=row['Borough']

#lets see what we got
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront
# 6      M5A  Downtown Toronto       Regent Park
# 7      M6A        North York  Lawrence Heights

# %%
#grouping by Boroughs and showing the result
res=df.groupby(['Postcode'],as_index=False).agg(lambda x: "%s" % ', '.join(x.unique())) 

#reset indexes in dataframe       
df.reset_index()

#lets see what we have as result
res
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Rouge, Malvern
# 1               Highland Creek, Rouge Hill, Port Union
# 2                    Guildwood, Morningside, West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          East Birchmount Park, Ionview, Kennedy Park
# 7                      Clairlea, Golden Mile, Oakridge
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Birch Cliff, Cliffside West
# 10   Dorset Park, Scarborough Town Centre, Wexford ...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Clarks Corners, Sullivan, Tam O'Shanter
# 14   Agincourt North, L'Amoreaux East, Milliken, St...
# 15                       L'Amoreaux West, Steeles West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Fairview, Henry Farm, Oriole
# 19                                     Bayview Village
# 20                            Silver Hills, York Mills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Flemingdon Park, Don Mills South
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                     Northwood Park, York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dovercourt Village, Dufferin
# 77                            Little Portugal, Trinity
# 78        Brockton, Exhibition Place, Parkdale Village
# 79            Maple Leaf Park, North Park, Upwood Park
# 80      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 81                       The Junction North, Runnymede
# 82                       High Park, The Junction South
# 83                              Parkdale, Roncesvalles
# 84                                  Runnymede, Swansea
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89                              Alderwood, Long Branch
# 90       The Kingsway, Montgomery Road, Old Mill North
# 91   Humber Bay, King's Mill Park, Kingsway Park So...
# 92   Kingsway Park South West, Mimico NW, The Queen...
# 93                                    Islington Avenue
# 94   Cloverdale, Islington, Martin Grove, Princess ...
# 95   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 96                                       Humber Summit
# 97                                    Emery, Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Kingsview Village, Martin Grove Gardens, Richv...
# 101  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
#lets see what shape do we have here
res.shape
# Out:
# (103, 3)

# %% [markdown]
# <h2>Part 2 - Fetching geodata</h2>

# %%
#installing GeoCoder anв import
# !pip install geocoder
import geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 7.3MB/s ta 0:00:01
# Requirement not upgraded as not directly required: click in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement not upgraded as not directly required: six in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: future in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from geocoder)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->geocoder)
# Requirement not upgraded as not directly required: decorator in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ratelim->geocoder)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
#define url
url = 'https://cocl.us/Geospatial_data'

#read coordinates from csv to dataframe
coordDF=pd.read_csv(url)

#watch new dataframe
coordDF.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#rename Postal Code column to Postcode
coordDF = coordDF.rename(columns={'Postal Code': 'Postcode'})
coordDF.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
#merge 2 dataframes
rezdf = coordDF.merge(res, on='Postcode', how='left')
rezdf.head()
# Out:
#   Postcode   Latitude  Longitude      Borough  \
# 0      M1B  43.806686 -79.194353  Scarborough
# 1      M1C  43.784535 -79.160497  Scarborough
# 2      M1E  43.763573 -79.188711  Scarborough
# 3      M1G  43.770992 -79.216917  Scarborough
# 4      M1H  43.773136 -79.239476  Scarborough
#
#                             Neighbourhood
# 0                          Rouge, Malvern
# 1  Highland Creek, Rouge Hill, Port Union
# 2       Guildwood, Morningside, West Hill
# 3                                  Woburn
# 4                               Cedarbrae

# %%
#change sequence of columns
rezdf = rezdf[['Postcode', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude']]
rezdf.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# <h2>Part 3 - "Explore and cluster the neighborhoods in Toronto"</h2>
# <h1 style="color:red;">Task: show on map all the police stations in 10 km radius where Borough == Scarborough</h1>

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  22.29 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  32.35 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  43.25 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  30.69 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  34.09 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  40.51 MB/s
# Folium installed
# Libraries imported.

# %%
#Define Foursquare Credentials and Version and limit
CLIENT_ID = '5C0SBFWN5NJLFSCNXDUH2O2BRCF1SPBDEJKXB34CLS1JJZQK' # your Foursquare ID
CLIENT_SECRET = 'MKJLMSSBH4IIKRFZPS55TKIDVU1VMEJJ1ILYYOW0GHHN0QF2' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30

# %%
#take all the postcodes of Scarborough
scarcodes=rezdf.loc[rezdf['Borough'] == 'Scarborough']
scarcodes
# Out:
#    Postcode      Borough                                      Neighbourhood  \
# 0       M1B  Scarborough                                     Rouge, Malvern
# 1       M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2       M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3       M1G  Scarborough                                             Woburn
# 4       M1H  Scarborough                                          Cedarbrae
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough        East Birchmount Park, Ionview, Kennedy Park
# 7       M1L  Scarborough                    Clairlea, Golden Mile, Oakridge
# 8       M1M  Scarborough    Cliffcrest, Cliffside, Scarborough Village West
# 9       M1N  Scarborough                        Birch Cliff, Cliffside West
# 10      M1P  Scarborough  Dorset Park, Scarborough Town Centre, Wexford ...
# 11      M1R  Scarborough                                  Maryvale, Wexford
# 12      M1S  Scarborough                                          Agincourt
# 13      M1T  Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 14      M1V  Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...
# 15      M1W  Scarborough                      L'Amoreaux West, Steeles West
# 16      M1X  Scarborough                                        Upper Rouge
#
#      Latitude  Longitude
# 0   43.806686 -79.194353
# 1   43.784535 -79.160497
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# 5   43.744734 -79.239476
# 6   43.727929 -79.262029
# 7   43.711112 -79.284577
# 8   43.716316 -79.239476
# 9   43.692657 -79.264848
# 10  43.757410 -79.273304
# 11  43.750072 -79.295849
# 12  43.794200 -79.262029
# 13  43.781638 -79.304302
# 14  43.815252 -79.284577
# 15  43.799525 -79.318389
# 16  43.836125 -79.205636

# %%
#lets define search query
search_query = 'police station'

#lets define radius = 10 km
radius = 10000

# %%
#lets assume that we will fetch police stations from the 10 km circle in the centre of Scarborough, which will be average of its Neighbourhood's Latitude & Longitude
center_lat=scarcodes.Latitude.sum() / scarcodes.Latitude.count()
center_lng=scarcodes.Longitude.sum() / scarcodes.Longitude.count()
print('Coordinates of the search area centre are: ', center_lat, center_lng)
# Out:
# Coordinates of the search area centre are:  43.7662288941 -79.2490852353

# %%
#define search URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, center_lat, center_lng, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5C0SBFWN5NJLFSCNXDUH2O2BRCF1SPBDEJKXB34CLS1JJZQK&client_secret=MKJLMSSBH4IIKRFZPS55TKIDVU1VMEJJ1ILYYOW0GHHN0QF2&ll=43.76622889411765,-79.24908523529412&v=20180604&query=police station&radius=10000&limit=30'

# %%
#results in JSON format
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c6ad340dd57977c04782f52'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'primary': True,
#       'shortName': 'Light Rail'}],
#     'hasPerk': False,
#     'id': '4b17097bf964a5204dc123e3',
#     'location': {'address': '1275 McCowan Rd',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Ellesmere Rd',
#      'distance': 986,
#      'formattedAddress': ['1275 McCowan Rd (at Ellesmere Rd)',
#       'Toronto ON M1P 2K2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77487442584537,
#        'lng': -79.25177693367004}],
#      'lat': 43.77487442584537,
#      'lng': -79.25177693367004,
#      'postalCode': 'M1P 2K2',
#      'state': 'ON'},
#     'name': 'McCowan RT Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'primary': True,
#       'shortName': 'Light Rail'}],
#     'hasPerk': False,
#     'id': '4b61e094f964a5209c282ae3',
#     'location': {'address': '300 Borough Dr',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1141,
#      'formattedAddress': ['300 Borough Dr', 'Toronto ON M1P 4P5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77454130809508,
#        'lng': -79.25739079713821}],
#      'lat': 43.77454130809508,
#      'lng': -79.25739079713821,
#      'postalCode': 'M1P 4P5',
#      'state': 'ON'},
#     'name': 'Scarborough Centre RT Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'primary': True,
#       'shortName': 'Bus Station'}],
#     'hasPerk': False,
#     'id': '500b6cbde4b001d6c599ef3f',
#     'location': {'address': '300 Borough dr',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'country': 'Canada',
#      'distance': 1145,
#      'formattedAddress': ['300 Borough dr', 'Scarborough ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.774406177958234,
#        'lng': -79.25774001667654}],
#      'lat': 43.774406177958234,
#      'lng': -79.25774001667654,
#      'state': 'ON'},
#     'name': 'Scarborough Centre Bus Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4ae9b80ef964a520d0b521e3',
#     'location': {'address': '2455 Eglinton Av E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Kennedy Rd',
#      'distance': 3922,
#      'formattedAddress': ['2455 Eglinton Av E (at Kennedy Rd)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73291798585667,
#        'lng': -79.26498413085938}],
#      'lat': 43.73291798585667,
#      'lng': -79.26498413085938,
#      'state': 'ON'},
#     'name': 'Kennedy Subway/RT Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'primary': True,
#       'shortName': 'Light Rail'}],
#     'hasPerk': False,
#     'id': '4b0bdcc3f964a520363423e3',
#     'location': {'address': '2444 Lawrence Ave E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Midland Ave.',
#      'distance': 2447,
#      'formattedAddress': ['2444 Lawrence Ave E (at Midland Ave.)',
#       'Toronto ON M1P 4S5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75038338963791,
#        'lng': -79.27019163966177}],
#      'lat': 43.75038338963791,
#      'lng': -79.27019163966177,
#      'postalCode': 'M1P 4S5',
#      'state': 'ON'},
#     'name': 'Lawrence East RT Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'primary': True,
#       'shortName': 'Light Rail'}],
#     'hasPerk': False,
#     'id': '4b0d3007f964a520734423e3',
#     'location': {'address': '2085 Midland Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1900,
#      'formattedAddress': ['2085 Midland Ave', 'Toronto ON M1P 3E4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77046627566385,
#        'lng': -79.27199006080627}],
#      'lat': 43.77046627566385,
#      'lng': -79.27199006080627,
#      'postalCode': 'M1P 3E4',
#      'state': 'ON'},
#     'name': 'Midland RT Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'primary': True,
#       'shortName': 'Light Rail'}],
#     'hasPerk': False,
#     'id': '4b0d2ef3f964a520674423e3',
#     'location': {'address': '1025 Ellesmere Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Midland Ave',
#      'distance': 2189,
#      'formattedAddress': ['1025 Ellesmere Ave (at Midland Ave)',
#       'Toronto ON M1P 2L7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.766811293185015,
#        'lng': -79.27630975842476}],
#      'lat': 43.766811293185015,
#      'lng': -79.27630975842476,
#      'postalCode': 'M1P 2L7',
#      'state': 'ON'},
#     'name': 'Ellesmere RT Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'primary': True,
#       'shortName': 'Police Station'}],
#     'hasPerk': False,
#     'id': '4e41494a6284809c9f3d1412',
#     'location': {'address': '242 Milner Av.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 2709,
#      'formattedAddress': ['242 Milner Av.', 'Toronto ON M1S 5C4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7895633331839,
#        'lng': -79.23950232877971}],
#      'lat': 43.7895633331839,
#      'lng': -79.23950232877971,
#      'postalCode': 'M1S 5C4',
#      'state': 'ON'},
#     'name': 'Toronto Police Service - 42 Division',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4b5632acf964a520e20428e3',
#     'location': {'address': '4105 Kingston Road',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Celeste Dr.',
#      'distance': 4265,
#      'formattedAddress': ['4105 Kingston Road (at Celeste Dr.)',
#       'Toronto ON M1E 2M3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.754976871435844,
#        'lng': -79.19837243831087}],
#      'lat': 43.754976871435844,
#      'lng': -79.19837243831087,
#      'postalCode': 'M1E 2M3',
#      'state': 'ON'},
#     'name': 'Guildwood GO Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4b17084cf964a52038c123e3',
#     'location': {'address': '777 Victoria Park Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Danforth',
#      'distance': 8558,
#      'formattedAddress': ['777 Victoria Park Ave (at Danforth)',
#       'Toronto ON M4B 2E2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.69488264493771,
#        'lng': -79.28873509168625}],
#      'lat': 43.69488264493771,
#      'lng': -79.28873509168625,
#      'postalCode': 'M4B 2E2',
#      'state': 'ON'},
#     'name': 'Victoria Park Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4ae89c26f964a520d1b021e3',
#     'location': {'address': '2550 Danforth Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Main St',
#      'distance': 9570,
#      'formattedAddress': ['2550 Danforth Ave (at Main St)',
#       'Toronto ON M4C 1L4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.68910856344984,
#        'lng': -79.30166156422199}],
#      'lat': 43.68910856344984,
#      'lng': -79.30166156422199,
#      'postalCode': 'M4C 1L4',
#      'state': 'ON'},
#     'name': 'Main Street Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4b1fb09bf964a520152824e3',
#     'location': {'address': '2467 Eglinton Ave E',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'country': 'Canada',
#      'crossStreet': 'btwn Kennedy Rd & Midland Ave',
#      'distance': 3928,
#      'formattedAddress': ['2467 Eglinton Ave E (btwn Kennedy Rd & Midland Ave)',
#       'Scarborough ON M1K 2R1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73227476873184,
#        'lng': -79.26241750386065}],
#      'lat': 43.73227476873184,
#      'lng': -79.26241750386065,
#      'postalCode': 'M1K 2R1',
#      'state': 'ON'},
#     'name': 'Kennedy GO Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4aef7f5ff964a520e4d821e3',
#     'location': {'address': '3276 St Clair Ave E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Warden Ave',
#      'distance': 6596,
#      'formattedAddress': ['3276 St Clair Ave E (at Warden Ave)',
#       'Toronto ON M1L 1W1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.71122905571982,
#        'lng': -79.27960224480387}],
#      'lat': 43.71122905571982,
#      'lng': -79.27960224480387,
#      'postalCode': 'M1L 1W1',
#      'state': 'ON'},
#     'name': 'Warden Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4aeb974df964a52096c321e3',
#     'location': {'address': '1700 Sheppard Ave. E.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Don Mills Rd.',
#      'distance': 7905,
#      'formattedAddress': ['1700 Sheppard Ave. E. (at Don Mills Rd.)',
#       'Toronto ON M2J 5G9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.775501921683805,
#        'lng': -79.3465930223465}],
#      'lat': 43.775501921683805,
#      'lng': -79.3465930223465,
#      'postalCode': 'M2J 5G9',
#      'state': 'ON'},
#     'name': 'Don Mills Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4b13c0a4f964a520dd9823e3',
#     'location': {'address': '2995 Eglinton Ave. East',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'country': 'Canada',
#      'crossStreet': 'at Bellamy Rd.',
#      'distance': 3247,
#      'formattedAddress': ['2995 Eglinton Ave. East (at Bellamy Rd.)',
#       'Scarborough ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.739701465456726,
#        'lng': -79.23228116650037}],
#      'lat': 43.739701465456726,
#      'lng': -79.23228116650037,
#      'state': 'ON'},
#     'name': 'Eglinton GO Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4ba9fd15f964a520e7413ae3',
#     'location': {'address': '4100 Sheppard Ave. E',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'country': 'Canada',
#      'crossStreet': 'Between Kennedy Rd. & Midland Ave.',
#      'distance': 3573,
#      'formattedAddress': ['4100 Sheppard Ave. E (Between Kennedy Rd. & Midland Ave.)',
#       'Scarborough ON M1S 1S9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.785801757808315,
#        'lng': -79.28432350540315}],
#      'lat': 43.785801757808315,
#      'lng': -79.28432350540315,
#      'postalCode': 'M1S 1S9',
#      'state': 'ON'},
#     'name': 'Agincourt GO Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'primary': True,
#       'shortName': 'Business Center'}],
#     'hasPerk': False,
#     'id': '56b3bc48498e8bc7c74e84f9',
#     'location': {'address': '103-105 Gordon Baker Road',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 5169,
#      'formattedAddress': ['103-105 Gordon Baker Road',
#       'Toronto ON M2H 3P8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76179913614034,
#        'lng': -79.31309824845854}],
#      'lat': 43.76179913614034,
#      'lng': -79.31309824845854,
#      'postalCode': 'M2H 3P8',
#      'state': 'ON'},
#     'name': 'The Police Credit Union',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4ae47a19f964a520d09a21e3',
#     'location': {'address': '1209 Sheppard Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Old Leslie St.',
#      'distance': 9468,
#      'formattedAddress': ['1209 Sheppard Ave. (at Old Leslie St.)',
#       'Toronto ON M2K 3A6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77062347898726,
#        'lng': -79.36671014750037}],
#      'lat': 43.77062347898726,
#      'lng': -79.36671014750037,
#      'postalCode': 'M2K 3A6',
#      'state': 'ON'},
#     'name': 'Leslie Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'primary': True,
#       'shortName': 'Police Station'}],
#     'hasPerk': False,
#     'id': '4e8a27feb80395ac8b5df35a',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1221,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.77524,
#        'lng': -79.257747}],
#      'lat': 43.77524,
#      'lng': -79.257747,
#      'state': 'ON'},
#     'name': 'Toronto Police Services',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4aeb7becf964a5208ec221e3',
#     'location': {'address': '1568 Danforth Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Coxwell Ave.',
#      'distance': 10706,
#      'formattedAddress': ['1568 Danforth Ave. (at Coxwell Ave.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.68568356290908,
#        'lng': -79.3218145309042}],
#      'lat': 43.68568356290908,
#      'lng': -79.3218145309042,
#      'state': 'ON'},
#     'name': 'Coxwell Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'primary': True,
#       'shortName': 'Police Station'}],
#     'hasPerk': False,
#     'id': '577172a9498e4989c3a271e3',
#     'location': {'address': '330 Progress Avenue',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'country': 'Canada',
#      'distance': 1721,
#      'formattedAddress': ['330 Progress Avenue', 'Scarborough ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.774605,
#        'lng': -79.26709}],
#      'lat': 43.774605,
#      'lng': -79.26709,
#      'state': 'ON'},
#     'name': 'Toronto Police Property Unit',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4afd8b76f964a520762822e3',
#     'location': {'address': '5117 Sheppard Ave. E',
#      'cc': 'CA',
#      'city': 'Scarborough',
#      'country': 'Canada',
#      'crossStreet': 'at Markham Rd.',
#      'distance': 3061,
#      'formattedAddress': ['5117 Sheppard Ave. E (at Markham Rd.)',
#       'Scarborough ON M1S 4N8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.79264410001942,
#        'lng': -79.23847252989981}],
#      'lat': 43.79264410001942,
#      'lng': -79.23847252989981,
#      'postalCode': 'M1S 4N8',
#      'state': 'ON'},
#     'name': 'Markham Station Restaurant',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'primary': True,
#       'shortName': 'Metro'}],
#     'hasPerk': False,
#     'id': '4aef91d3f964a52051d921e3',
#     'location': {'address': '2072 Danforth Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Woodbine Ave',
#      'distance': 10253,
#      'formattedAddress': ['2072 Danforth Ave (at Woodbine Ave)',
#       'Toronto ON M4C 1J6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6865003419232,
#        'lng': -79.31290581822395}],
#      'lat': 43.6865003419232,
#      'lng': -79.31290581822395,
#      'postalCode': 'M4C 1J6',
#      'state': 'ON'},
#     'name': 'Woodbine Subway Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'primary': True,
#       'shortName': 'Police Station'}],
#     'hasPerk': False,
#     'id': '4fedfefde4b0099eb070e3db',
#     'location': {'address': '2222 Eglinton Ave. E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Birchmount Rd.',
#      'distance': 4568,
#      'formattedAddress': ['2222 Eglinton Ave. E (at Birchmount Rd.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.7304114211943,
#        'lng': -79.27682424060959}],
#      'lat': 43.7304114211943,
#      'lng': -79.27682424060959,
#      'state': 'ON'},
#     'name': 'Toronto Police Service - 41 Division',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'primary': True,
#       'shortName': 'Government'}],
#     'hasPerk': False,
#     'id': '4f9ca7807b0c57c52ae15980',
#     'location': {'address': '2900 Lawrence Ave E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1386,
#      'formattedAddress': ['2900 Lawrence Ave E',
#       'Toronto ON M1P 2T8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.75418661803952,
#        'lng': -79.25348281860352}],
#      'lat': 43.75418661803952,
#      'lng': -79.25348281860352,
#      'postalCode': 'M1P 2T8',
#      'state': 'ON'},
#     'name': 'Toronto EMS Station 28',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4b2b7f39f964a520dbb624e3',
#     'location': {'address': '3615 St. Clair Ave. E',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Midland & Reeve',
#      'distance': 5474,
#      'formattedAddress': ['3615 St. Clair Ave. E (btwn Midland & Reeve)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.717221308069384,
#        'lng': -79.25474805484917}],
#      'lat': 43.717221308069384,
#      'lng': -79.25474805484917,
#      'state': 'ON'},
#     'name': 'Scarborough GO Station',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/newsstand_',
#        'suffix': '.png'},
#       'id': '4f04ad622fb6e1c99f3db0b9',
#       'name': 'Newsstand',
#       'pluralName': 'Newsstands',
#       'primary': True,
#       'shortName': 'Newsstand'}],
#     'hasPerk': False,
#     'id': '5244b44111d2108e822ae871',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'crossStreet': 'Inside Scarborough Centre RT Station',
#      'distance': 1401,
#      'formattedAddress': ['Inside Scarborough Centre RT Station', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.777198505500365,
#        'lng': -79.25764413011635}],
#      'lat': 43.777198505500365,
#      'lng': -79.25764413011635},
#     'name': 'Gateway News Stand (Scarborough RT station)',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_policestation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d12e941735',
#       'name': 'Police Station',
#       'pluralName': 'Police Stations',
#       'primary': True,
#       'shortName': 'Police Station'}],
#     'hasPerk': False,
#     'id': '59a69d13f62e0924f3411ad2',
#     'location': {'address': '330 Progress Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1815,
#      'formattedAddress': ['330 Progress Ave', 'Toronto ON M1P 2Z4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.774368,
#        'lng': -79.268654}],
#      'lat': 43.774368,
#      'lng': -79.268654,
#      'postalCode': 'M1P 2Z4',
#      'state': 'ON'},
#     'name': 'Toronto Police Service, Parking Enforcement Unit',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'primary': True,
#       'shortName': 'Parking'}],
#     'hasPerk': False,
#     'id': '4dd837d0e4cd37c893c056d1',
#     'location': {'address': '2995 Eglinton Ave East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 3250,
#      'formattedAddress': ['2995 Eglinton Ave East', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.73998454381005,
#        'lng': -79.23136227165732}],
#      'lat': 43.73998454381005,
#      'lng': -79.23136227165732,
#      'state': 'ON'},
#     'name': 'Eglinton Go Station Parking Lot',
#     'referralId': 'v-1550504768'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d129951735',
#       'name': 'Train Station',
#       'pluralName': 'Train Stations',
#       'primary': True,
#       'shortName': 'Train Station'}],
#     'hasPerk': False,
#     'id': '4b599b94f964a520a98e28e3',
#     'location': {'address': '7970 Kennedy Rd.',
#      'cc': 'CA',
#      'city': 'Markham',
#      'country': 'Canada',
#      'crossStreet': 'at Hwy. 7',
#      'distance': 10863,
#      'formattedAddress': ['7970 Kennedy Rd. (at Hwy. 7)',
#       'Markham ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.85158249946059,
#        'lng': -79.3146564773931}],
#      'lat': 43.85158249946059,
#      'lng': -79.3146564773931,
#      'state': 'ON'},
#     'name': 'Unionville GO Station',
#     'referralId': 'v-1550504768'}]}}

# %%
# assign relevant part of JSON to venues
police_venues = results['response']['venues']

# tranform venues into a dataframe
police_df = json_normalize(police_venues)

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in police_df.columns if col.startswith('location.')] + ['id']
police_df_filtered = police_df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
police_df_filtered['categories'] = police_df_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
police_df_filtered.columns = [column.split('.')[-1] for column in police_df_filtered.columns]

#lets see what we got here
police_df_filtered
# Out:
#                                                 name           categories  \
# 0                                 McCowan RT Station   Light Rail Station
# 1                      Scarborough Centre RT Station   Light Rail Station
# 2                     Scarborough Centre Bus Station          Bus Station
# 3                          Kennedy Subway/RT Station        Metro Station
# 4                           Lawrence East RT Station   Light Rail Station
# 5                                 Midland RT Station   Light Rail Station
# 6                               Ellesmere RT Station   Light Rail Station
# 7               Toronto Police Service - 42 Division       Police Station
# 8                               Guildwood GO Station        Train Station
# 9                       Victoria Park Subway Station        Metro Station
# 10                        Main Street Subway Station        Metro Station
# 11                                Kennedy GO Station        Train Station
# 12                             Warden Subway Station        Metro Station
# 13                          Don Mills Subway Station        Metro Station
# 14                               Eglinton GO Station        Train Station
# 15                              Agincourt GO Station        Train Station
# 16                           The Police Credit Union      Business Center
# 17                             Leslie Subway Station        Metro Station
# 18                           Toronto Police Services       Police Station
# 19                            Coxwell Subway Station        Metro Station
# 20                      Toronto Police Property Unit       Police Station
# 21                        Markham Station Restaurant                Diner
# 22                           Woodbine Subway Station        Metro Station
# 23              Toronto Police Service - 41 Division       Police Station
# 24                            Toronto EMS Station 28  Government Building
# 25                            Scarborough GO Station        Train Station
# 26       Gateway News Stand (Scarborough RT station)            Newsstand
# 27  Toronto Police Service, Parking Enforcement Unit       Police Station
# 28                   Eglinton Go Station Parking Lot              Parking
# 29                             Unionville GO Station        Train Station
#
#                       address  cc         city country  \
# 0             1275 McCowan Rd  CA      Toronto  Canada
# 1              300 Borough Dr  CA      Toronto  Canada
# 2              300 Borough dr  CA  Scarborough  Canada
# 3          2455 Eglinton Av E  CA      Toronto  Canada
# 4         2444 Lawrence Ave E  CA      Toronto  Canada
# 5            2085 Midland Ave  CA      Toronto  Canada
# 6          1025 Ellesmere Ave  CA      Toronto  Canada
# 7              242 Milner Av.  CA      Toronto  Canada
# 8          4105 Kingston Road  CA      Toronto  Canada
# 9       777 Victoria Park Ave  CA      Toronto  Canada
# 10          2550 Danforth Ave  CA      Toronto  Canada
# 11        2467 Eglinton Ave E  CA  Scarborough  Canada
# 12        3276 St Clair Ave E  CA      Toronto  Canada
# 13      1700 Sheppard Ave. E.  CA      Toronto  Canada
# 14    2995 Eglinton Ave. East  CA  Scarborough  Canada
# 15       4100 Sheppard Ave. E  CA  Scarborough  Canada
# 16  103-105 Gordon Baker Road  CA      Toronto  Canada
# 17         1209 Sheppard Ave.  CA      Toronto  Canada
# 18                        NaN  CA      Toronto  Canada
# 19         1568 Danforth Ave.  CA      Toronto  Canada
# 20        330 Progress Avenue  CA  Scarborough  Canada
# 21       5117 Sheppard Ave. E  CA  Scarborough  Canada
# 22          2072 Danforth Ave  CA      Toronto  Canada
# 23       2222 Eglinton Ave. E  CA      Toronto  Canada
# 24        2900 Lawrence Ave E  CA      Toronto  Canada
# 25      3615 St. Clair Ave. E  CA      Toronto  Canada
# 26                        NaN  CA          NaN  Canada
# 27           330 Progress Ave  CA      Toronto  Canada
# 28     2995 Eglinton Ave East  CA      Toronto  Canada
# 29           7970 Kennedy Rd.  CA      Markham  Canada
#
#                              crossStreet  distance  \
# 0                        at Ellesmere Rd       986
# 1                                    NaN      1141
# 2                                    NaN      1145
# 3                          at Kennedy Rd      3922
# 4                        at Midland Ave.      2447
# 5                                    NaN      1900
# 6                         at Midland Ave      2189
# 7                                    NaN      2709
# 8                         at Celeste Dr.      4265
# 9                            at Danforth      8558
# 10                            at Main St      9570
# 11         btwn Kennedy Rd & Midland Ave      3928
# 12                         at Warden Ave      6596
# 13                      at Don Mills Rd.      7905
# 14                        at Bellamy Rd.      3247
# 15    Between Kennedy Rd. & Midland Ave.      3573
# 16                                   NaN      5169
# 17                     at Old Leslie St.      9468
# 18                                   NaN      1221
# 19                       at Coxwell Ave.     10706
# 20                                   NaN      1721
# 21                        at Markham Rd.      3061
# 22                       at Woodbine Ave     10253
# 23                     at Birchmount Rd.      4568
# 24                                   NaN      1386
# 25                  btwn Midland & Reeve      5474
# 26  Inside Scarborough Centre RT Station      1401
# 27                                   NaN      1815
# 28                                   NaN      3250
# 29                             at Hwy. 7     10863
#
#                                      formattedAddress  \
# 0   [1275 McCowan Rd (at Ellesmere Rd), Toronto ON...
# 1        [300 Borough Dr, Toronto ON M1P 4P5, Canada]
# 2            [300 Borough dr, Scarborough ON, Canada]
# 3   [2455 Eglinton Av E (at Kennedy Rd), Toronto O...
# 4   [2444 Lawrence Ave E (at Midland Ave.), Toront...
# 5      [2085 Midland Ave, Toronto ON M1P 3E4, Canada]
# 6   [1025 Ellesmere Ave (at Midland Ave), Toronto ...
# 7        [242 Milner Av., Toronto ON M1S 5C4, Canada]
# 8   [4105 Kingston Road (at Celeste Dr.), Toronto ...
# 9   [777 Victoria Park Ave (at Danforth), Toronto ...
# 10  [2550 Danforth Ave (at Main St), Toronto ON M4...
# 11  [2467 Eglinton Ave E (btwn Kennedy Rd & Midlan...
# 12  [3276 St Clair Ave E (at Warden Ave), Toronto ...
# 13  [1700 Sheppard Ave. E. (at Don Mills Rd.), Tor...
# 14  [2995 Eglinton Ave. East (at Bellamy Rd.), Sca...
# 15  [4100 Sheppard Ave. E (Between Kennedy Rd. & M...
# 16  [103-105 Gordon Baker Road, Toronto ON M2H 3P8...
# 17  [1209 Sheppard Ave. (at Old Leslie St.), Toron...
# 18                               [Toronto ON, Canada]
# 19  [1568 Danforth Ave. (at Coxwell Ave.), Toronto...
# 20      [330 Progress Avenue, Scarborough ON, Canada]
# 21  [5117 Sheppard Ave. E (at Markham Rd.), Scarbo...
# 22  [2072 Danforth Ave (at Woodbine Ave), Toronto ...
# 23  [2222 Eglinton Ave. E (at Birchmount Rd.), Tor...
# 24  [2900 Lawrence Ave E, Toronto ON M1P 2T8, Canada]
# 25  [3615 St. Clair Ave. E (btwn Midland & Reeve),...
# 26     [Inside Scarborough Centre RT Station, Canada]
# 27     [330 Progress Ave, Toronto ON M1P 2Z4, Canada]
# 28       [2995 Eglinton Ave East, Toronto ON, Canada]
# 29  [7970 Kennedy Rd. (at Hwy. 7), Markham ON, Can...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lng': -79.25177693367004, 'label': 'display...  43.774874 -79.251777
# 1   [{'lng': -79.25739079713821, 'label': 'display...  43.774541 -79.257391
# 2   [{'lng': -79.25774001667654, 'label': 'display...  43.774406 -79.257740
# 3   [{'lng': -79.26498413085938, 'label': 'display...  43.732918 -79.264984
# 4   [{'lng': -79.27019163966177, 'label': 'display...  43.750383 -79.270192
# 5   [{'lng': -79.27199006080627, 'label': 'display...  43.770466 -79.271990
# 6   [{'lng': -79.27630975842476, 'label': 'display...  43.766811 -79.276310
# 7   [{'lng': -79.23950232877971, 'label': 'display...  43.789563 -79.239502
# 8   [{'lng': -79.19837243831087, 'label': 'display...  43.754977 -79.198372
# 9   [{'lng': -79.28873509168625, 'label': 'display...  43.694883 -79.288735
# 10  [{'lng': -79.30166156422199, 'label': 'display...  43.689109 -79.301662
# 11  [{'lng': -79.26241750386065, 'label': 'display...  43.732275 -79.262418
# 12  [{'lng': -79.27960224480387, 'label': 'display...  43.711229 -79.279602
# 13  [{'lng': -79.3465930223465, 'label': 'display'...  43.775502 -79.346593
# 14  [{'lng': -79.23228116650037, 'label': 'display...  43.739701 -79.232281
# 15  [{'lng': -79.28432350540315, 'label': 'display...  43.785802 -79.284324
# 16  [{'lng': -79.31309824845854, 'label': 'display...  43.761799 -79.313098
# 17  [{'lng': -79.36671014750037, 'label': 'display...  43.770623 -79.366710
# 18  [{'lng': -79.257747, 'label': 'display', 'lat'...  43.775240 -79.257747
# 19  [{'lng': -79.3218145309042, 'label': 'display'...  43.685684 -79.321815
# 20  [{'lng': -79.26709, 'label': 'display', 'lat':...  43.774605 -79.267090
# 21  [{'lng': -79.23847252989981, 'label': 'display...  43.792644 -79.238473
# 22  [{'lng': -79.31290581822395, 'label': 'display...  43.686500 -79.312906
# 23  [{'lng': -79.27682424060959, 'label': 'display...  43.730411 -79.276824
# 24  [{'lng': -79.25348281860352, 'label': 'display...  43.754187 -79.253483
# 25  [{'lng': -79.25474805484917, 'label': 'display...  43.717221 -79.254748
# 26  [{'lng': -79.25764413011635, 'label': 'display...  43.777199 -79.257644
# 27  [{'lng': -79.268654, 'label': 'display', 'lat'...  43.774368 -79.268654
# 28  [{'lng': -79.23136227165732, 'label': 'display...  43.739985 -79.231362
# 29  [{'lng': -79.3146564773931, 'label': 'display'...  43.851582 -79.314656
#
#    postalCode state                        id
# 0     M1P 2K2    ON  4b17097bf964a5204dc123e3
# 1     M1P 4P5    ON  4b61e094f964a5209c282ae3
# 2         NaN    ON  500b6cbde4b001d6c599ef3f
# 3         NaN    ON  4ae9b80ef964a520d0b521e3
# 4     M1P 4S5    ON  4b0bdcc3f964a520363423e3
# 5     M1P 3E4    ON  4b0d3007f964a520734423e3
# 6     M1P 2L7    ON  4b0d2ef3f964a520674423e3
# 7     M1S 5C4    ON  4e41494a6284809c9f3d1412
# 8     M1E 2M3    ON  4b5632acf964a520e20428e3
# 9     M4B 2E2    ON  4b17084cf964a52038c123e3
# 10    M4C 1L4    ON  4ae89c26f964a520d1b021e3
# 11    M1K 2R1    ON  4b1fb09bf964a520152824e3
# 12    M1L 1W1    ON  4aef7f5ff964a520e4d821e3
# 13    M2J 5G9    ON  4aeb974df964a52096c321e3
# 14        NaN    ON  4b13c0a4f964a520dd9823e3
# 15    M1S 1S9    ON  4ba9fd15f964a520e7413ae3
# 16    M2H 3P8    ON  56b3bc48498e8bc7c74e84f9
# 17    M2K 3A6    ON  4ae47a19f964a520d09a21e3
# 18        NaN    ON  4e8a27feb80395ac8b5df35a
# 19        NaN    ON  4aeb7becf964a5208ec221e3
# 20        NaN    ON  577172a9498e4989c3a271e3
# 21    M1S 4N8    ON  4afd8b76f964a520762822e3
# 22    M4C 1J6    ON  4aef91d3f964a52051d921e3
# 23        NaN    ON  4fedfefde4b0099eb070e3db
# 24    M1P 2T8    ON  4f9ca7807b0c57c52ae15980
# 25        NaN    ON  4b2b7f39f964a520dbb624e3
# 26        NaN   NaN  5244b44111d2108e822ae871
# 27    M1P 2Z4    ON  59a69d13f62e0924f3411ad2
# 28        NaN    ON  4dd837d0e4cd37c893c056d1
# 29        NaN    ON  4b599b94f964a520a98e28e3

# %%
venues_map = folium.Map(location=[center_lat,center_lng], zoom_start=12) # generate map centred around the search area centre

# add a red circle marker to represent the search area centre
folium.features.CircleMarker(
    [center_lat, center_lng],
    radius=5,
    color='red',
    popup='The police station search area centre',
    fill = True,
    fill_color = 'red',
    fill_opacity = 1
).add_to(venues_map)

# add the police venues as blue circle markers
for lat, lng, label in zip(police_df_filtered.lat, police_df_filtered.lng, police_df_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=3,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=1
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
