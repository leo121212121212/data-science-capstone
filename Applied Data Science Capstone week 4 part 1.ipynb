# %% [markdown]
# <H3>Hello, I will be using code comments instead of markdown cells</H3>
# <h4>have a nice day!</h4>

# %%
# import needed libs
import sys
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import math

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  22.40 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  30.32 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  43.85 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  31.84 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  35.02 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  42.36 MB/s
# Folium installed
# Libraries imported.

# %%
#Define Foursquare Credentials and Version and limit
CLIENT_ID = 'DY0YEQZ1Z4JHB3E2ODKZTJ31GLJ4LHWXNB5FHFDNZZ13ZH0R' # your Foursquare ID
CLIENT_SECRET = 'WBMCEP1BGLEGBHR2DZAKJZBOS5CBRL4UFOLDWAPEFKNOE23Y' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10000

# %%
#NY centre coordinates
ny_lat=40.730610
ny_lng=-73.935242

#lets define radius of search
area=1213.37

#lets find radius in metres
radius = math.sqrt(area/3.14)*1000

#lets define search queries
search_query = 'Veterinarian'

print('Coordinates of the search area centre are: ', ny_lat, ny_lng, ', search radius: ', radius , 'meters')
# Out:
# Coordinates of the search area centre are:  40.73061 -73.935242 , search radius:  19657.659242111735 meters

# %%
#define search URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, ny_lat, ny_lng, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=DY0YEQZ1Z4JHB3E2ODKZTJ31GLJ4LHWXNB5FHFDNZZ13ZH0R&client_secret=WBMCEP1BGLEGBHR2DZAKJZBOS5CBRL4UFOLDWAPEFKNOE23Y&ll=40.73061,-73.935242&v=20180604&query=Veterinarian&radius=19657.659242111735&limit=10000'

# %%
#results in JSON format
results = requests.get(url).json()

# %%
#lets look at search results in JSON format
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c6c0af3351e3d13a9c4edaa'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4b91517df964a520b3b233e3',
#     'location': {'address': '32-41 Steinway St #R',
#      'cc': 'US',
#      'city': 'Astoria',
#      'country': 'United States',
#      'distance': 3300,
#      'formattedAddress': ['32-41 Steinway St #R',
#       'Astoria, NY 11103',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75782592499892,
#        'lng': -73.91970744124593}],
#      'lat': 40.75782592499892,
#      'lng': -73.91970744124593,
#      'postalCode': '11103',
#      'state': 'NY'},
#     'name': 'Steinway Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4c3c83e04bc9a5932fbcd271',
#     'location': {'address': '340 E 11th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'btwn 1st & 2nd Ave',
#      'distance': 4158,
#      'formattedAddress': ['340 E 11th St (btwn 1st & 2nd Ave)',
#       'New York, NY 10003',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.729613728225495,
#        'lng': -73.9845220240651}],
#      'lat': 40.729613728225495,
#      'lng': -73.9845220240651,
#      'postalCode': '10003',
#      'state': 'NY'},
#     'name': 'The Village Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4cb86d6ea33bb1f713eb80fd',
#     'location': {'cc': 'US',
#      'city': 'Middle Village',
#      'country': 'United States',
#      'distance': 5526,
#      'formattedAddress': ['Middle Village, NY 11379', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71308945030248,
#        'lng': -73.87394851383898}],
#      'lat': 40.71308945030248,
#      'lng': -73.87394851383898,
#      'postalCode': '11379',
#      'state': 'NY'},
#     'name': 'A Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d100951735',
#       'name': 'Pet Store',
#       'pluralName': 'Pet Stores',
#       'primary': True,
#       'shortName': 'Pet Store'}],
#     'hasPerk': False,
#     'id': '56324b4d498eb5f26f97403d',
#     'location': {'address': '27-15 24th Ave',
#      'cc': 'US',
#      'city': 'Astoria',
#      'country': 'United States',
#      'distance': 5022,
#      'formattedAddress': ['27-15 24th Ave',
#       'Astoria, NY 11102',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.773623986347594,
#        'lng': -73.91728041463668}],
#      'lat': 40.773623986347594,
#      'lng': -73.91728041463668,
#      'postalCode': '11102',
#      'state': 'NY'},
#     'name': 'Dr. Pet Daddy Veterinarian, PC',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'primary': True,
#       'shortName': 'Pet Service'}],
#     'hasPerk': False,
#     'id': '55043316498e6198e7f41f46',
#     'location': {'address': '42-06 Steinway Street',
#      'cc': 'US',
#      'city': 'Astoria',
#      'country': 'United States',
#      'distance': 3286,
#      'formattedAddress': ['42-06 Steinway Street',
#       'Astoria, NY',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75765723326018,
#        'lng': -73.91963522518799}],
#      'lat': 40.75765723326018,
#      'lng': -73.91963522518799,
#      'state': 'NY'},
#     'name': 'steinway court veterinarian steinway court veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '54e1f61c498eee7bd0893ee5',
#     'location': {'address': '170 East 66th Street',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': '3rd ave and Lexington Ave',
#      'distance': 4446,
#      'formattedAddress': ['170 East 66th Street (3rd ave and Lexington Ave)',
#       'New York, NY 10065',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76297490010358,
#        'lng': -73.96614074707031}],
#      'lat': 40.76297490010358,
#      'lng': -73.96614074707031,
#      'postalCode': '10065',
#      'state': 'NY'},
#     'name': 'Dr. Cindy Bressler House Call Veterinarian NYC/Hamptons',
#     'referralId': 'v-1550584563',
#     'venuePage': {'id': '120586408'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4b8abb03f964a520107d32e3',
#     'location': {'address': '220 West ZEnd',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Broadway',
#      'distance': 6707,
#      'formattedAddress': ['220 West ZEnd (Broadway)',
#       'New York, NY 10023',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.779000444453196,
#        'lng': -73.98263275921593}],
#      'lat': 40.779000444453196,
#      'lng': -73.98263275921593,
#      'postalCode': '10023',
#      'state': 'NY'},
#     'name': 'City Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4e2af41da809f1b1640a346b',
#     'location': {'address': '170 W 96th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'Amsterdam',
#      'distance': 7621,
#      'formattedAddress': ['170 W 96th St (Amsterdam)',
#       'New York, NY 10025',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79384398521261,
#        'lng': -73.96991198344747}],
#      'lat': 40.79384398521261,
#      'lng': -73.96991198344747,
#      'postalCode': '10025',
#      'state': 'NY'},
#     'name': 'Symphony Vet Center',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4d948000af67370459027d09',
#     'location': {'address': '639 4th Ave',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'country': 'United States',
#      'crossStreet': '19th',
#      'distance': 8960,
#      'formattedAddress': ['639 4th Ave (19th)',
#       'Brooklyn, NY 11232',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.663775235306545,
#        'lng': -73.9944164320893}],
#      'lat': 40.663775235306545,
#      'lng': -73.9944164320893,
#      'postalCode': '11232',
#      'state': 'NY'},
#     'name': 'Park Slope Veterinary Center',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4bc08ba9920eb713e10b192c',
#     'location': {'address': '204 E 76th St',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 5000,
#      'formattedAddress': ['204 E 76th St',
#       'New York, NY 10021',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.771973,
#        'lng': -73.958382}],
#      'lat': 40.771973,
#      'lng': -73.958382,
#      'postalCode': '10021',
#      'state': 'NY'},
#     'name': 'Lenox Hill Veterinarians',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '5ab6c4ac9411f2343fa8168f',
#     'location': {'address': '1461 1st Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'distance': 4744,
#      'formattedAddress': ['1461 1st Ave',
#       'New York, NY 10075',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77070601,
#        'lng': -73.9543049}],
#      'lat': 40.77070601,
#      'lng': -73.9543049,
#      'postalCode': '10075',
#      'state': 'NY'},
#     'name': 'VetPronto - Mobile Veterinarians',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4ff0bd10e4b0581584aa40b2',
#     'location': {'address': 'Bell Blvd',
#      'cc': 'US',
#      'city': 'Bayside',
#      'country': 'United States',
#      'distance': 13939,
#      'formattedAddress': ['Bell Blvd', 'Bayside, NY 11361', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.767413299448314,
#        'lng': -73.77725200326664}],
#      'lat': 40.767413299448314,
#      'lng': -73.77725200326664,
#      'postalCode': '11361',
#      'state': 'NY'},
#     'name': 'Bayside Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1eb931735',
#       'name': 'Airport Terminal',
#       'pluralName': 'Airport Terminals',
#       'primary': True,
#       'shortName': 'Terminal'}],
#     'hasPerk': False,
#     'id': '4dd29efb1f6ef5f6ccd90498',
#     'location': {'address': '230-59 International Airport Center Blvd',
#      'cc': 'US',
#      'city': 'Jamaica',
#      'country': 'United States',
#      'distance': 17527,
#      'formattedAddress': ['230-59 International Airport Center Blvd',
#       'Jamaica, NY 11413',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.65057,
#        'lng': -73.756419}],
#      'lat': 40.65057,
#      'lng': -73.756419,
#      'postalCode': '11413',
#      'state': 'NY'},
#     'name': 'Port Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '50c360bbe4b0e0fa34731cf9',
#     'location': {'cc': 'US',
#      'city': 'Brooklyn',
#      'country': 'United States',
#      'distance': 15466,
#      'formattedAddress': ['Brooklyn, NY 11223', 'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.59537652752679,
#        'lng': -73.97725509387166}],
#      'lat': 40.59537652752679,
#      'lng': -73.97725509387166,
#      'postalCode': '11223',
#      'state': 'NY'},
#     'name': 'MVA Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '53c54703498efa2cc64107e7',
#     'location': {'address': '1707 3rd Ave',
#      'cc': 'US',
#      'city': 'New York',
#      'country': 'United States',
#      'crossStreet': 'E96th',
#      'distance': 6161,
#      'formattedAddress': ['1707 3rd Ave (E96th)',
#       'New York, NY 10128',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.784921029963094,
#        'lng': -73.94932555041507}],
#      'lat': 40.784921029963094,
#      'lng': -73.94932555041507,
#      'postalCode': '10128',
#      'state': 'NY'},
#     'name': 'Carnegie Hill Veterinarians',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4ea88fe46c253859bb057061',
#     'location': {'address': '654 5th Ave',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'country': 'United States',
#      'crossStreet': '19th and 20th Street',
#      'distance': 8988,
#      'formattedAddress': ['654 5th Ave (19th and 20th Street)',
#       'Brooklyn, NY 11215',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.662501218643335,
#        'lng': -73.99244072805992}],
#      'lat': 40.662501218643335,
#      'lng': -73.99244072805992,
#      'postalCode': '11215',
#      'state': 'NY'},
#     'name': 'Call Ahead Vet',
#     'referralId': 'v-1550584563',
#     'venuePage': {'id': '220032365'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '502198cfe4b0f661aadec0ef',
#     'location': {'address': '3402 John F. Kennedy Blvd',
#      'cc': 'US',
#      'city': 'Jersey City',
#      'country': 'United States',
#      'distance': 10334,
#      'formattedAddress': ['3402 John F. Kennedy Blvd',
#       'Jersey City, NJ 07307',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74849486,
#        'lng': -74.0554712}],
#      'lat': 40.74849486,
#      'lng': -74.0554712,
#      'postalCode': '07307',
#      'state': 'NJ'},
#     'name': 'Heights Veterinary Associates',
#     'referralId': 'v-1550584563',
#     'venuePage': {'id': '477923616'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'delivery': {'id': '923224',
#      'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#        'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50]},
#       'name': 'seamless'},
#      'url': 'https://www.seamless.com/menu/patricias-of-morris-park-1082-morris-park-ave-bronx/923224?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=923224'},
#     'hasPerk': False,
#     'id': '4ca63f8ef47ea143bec25e21',
#     'location': {'address': '1135 Morris Park Avenue',
#      'cc': 'US',
#      'city': 'Bronx',
#      'country': 'United States',
#      'crossStreet': 'Williamsbridge Rd',
#      'distance': 15060,
#      'formattedAddress': ['1135 Morris Park Avenue (Williamsbridge Rd)',
#       'Bronx, NY 10461',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.85024471419821,
#        'lng': -73.85180468158171}],
#      'lat': 40.85024471419821,
#      'lng': -73.85180468158171,
#      'postalCode': '10461',
#      'state': 'NY'},
#     'name': 'Animal Hospital of Morris Park',
#     'referralId': 'v-1550584563',
#     'venuePage': {'id': '368890572'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4b2112e9f964a5209e3624e3',
#     'location': {'address': '1252 Prospect A',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'country': 'United States',
#      'crossStreet': 'Reeve Pl',
#      'distance': 9347,
#      'formattedAddress': ['1252 Prospect A (Reeve Pl)',
#       'Brooklyn, NY',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.65257863,
#        'lng': -73.97616}],
#      'lat': 40.65257863,
#      'lng': -73.97616,
#      'state': 'NY'},
#     'name': 'Windsor Terrace Veterinarians',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4f9aac33e4b0d296c63372d0',
#     'location': {'address': '2 Forest St',
#      'cc': 'US',
#      'city': 'Montclair',
#      'country': 'United States',
#      'crossStreet': 'Glenridge Avenue',
#      'distance': 23738,
#      'formattedAddress': ['2 Forest St (Glenridge Avenue)',
#       'Montclair, NJ 07042',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79662735820694,
#        'lng': -74.20296154417177}],
#      'lat': 40.79662735820694,
#      'lng': -74.20296154417177,
#      'postalCode': '07042',
#      'state': 'NJ'},
#     'name': 'Dr. Brenda King, Veterinarian',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'primary': True,
#       'shortName': 'Pet Service'}],
#     'hasPerk': False,
#     'id': '4ccc4d7b2dc43704f948c608',
#     'location': {'address': '204-18 46th Ave',
#      'cc': 'US',
#      'city': 'Bayside',
#      'country': 'United States',
#      'distance': 13596,
#      'formattedAddress': ['204-18 46th Ave',
#       'Bayside, NY 11361',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75576940818088,
#        'lng': -73.77748755540115}],
#      'lat': 40.75576940818088,
#      'lng': -73.77748755540115,
#      'postalCode': '11361',
#      'state': 'NY'},
#     'name': 'Bayside Veterinary Ctr',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4c34d4594308b7136589c430',
#     'location': {'address': '289 Dongan Hills Ave',
#      'cc': 'US',
#      'city': 'Staten Island',
#      'country': 'United States',
#      'distance': 21042,
#      'formattedAddress': ['289 Dongan Hills Ave',
#       'Staten Island, NY 10305',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.58447354886878,
#        'lng': -74.09329178956217}],
#      'lat': 40.58447354886878,
#      'lng': -74.09329178956217,
#      'postalCode': '10305',
#      'state': 'NY'},
#     'name': 'Dongan Hills Veterinary Practice',
#     'referralId': 'v-1550584563'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'primary': True,
#       'shortName': 'Veterinarians'}],
#     'hasPerk': False,
#     'id': '4c1659707f7f2d7f0cd3e368',
#     'location': {'address': '2056 Jericho Tpke',
#      'cc': 'US',
#      'city': 'New Hyde Park',
#      'country': 'United States',
#      'crossStreet': 'at Brian St',
#      'distance': 22162,
#      'formattedAddress': ['2056 Jericho Tpke (at Brian St)',
#       'New Hyde Park, NY 11040',
#       'United States'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.73608540841573,
#        'lng': -73.67260024049297}],
#      'lat': 40.73608540841573,
#      'lng': -73.67260024049297,
#      'postalCode': '11040',
#      'state': 'NY'},
#     'name': 'Catnip & Carrots Veterinary Hospital',
#     'referralId': 'v-1550584563'}]}}

# %%
# assign relevant part of JSON to italian venues
venues = results['response']['venues']

# tranform venues into a dataframe
venues = json_normalize(venues)

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in venues.columns if col.startswith('location.')] + ['id']
venues_filter = venues.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
venues_filter['categories'] = venues_filter.apply(get_category_type, axis=1)

# clean column names by keeping only last term
venues_filter.columns = [column.split('.')[-1] for column in venues_filter.columns]

#lets see what we got here
print('DF shape: ', venues_filter.shape)
venues_filter
# Out:
# DF shape:  (23, 15)
#                                                  name        categories  \
# 0                               Steinway Veterinarian      Veterinarian
# 1                            The Village Veterinarian      Veterinarian
# 2                                      A Veterinarian      Veterinarian
# 3                      Dr. Pet Daddy Veterinarian, PC         Pet Store
# 4   steinway court veterinarian steinway court vet...       Pet Service
# 5   Dr. Cindy Bressler House Call Veterinarian NYC...      Veterinarian
# 6                                   City Veterinarian      Veterinarian
# 7                                 Symphony Vet Center      Veterinarian
# 8                        Park Slope Veterinary Center      Veterinarian
# 9                            Lenox Hill Veterinarians      Veterinarian
# 10                   VetPronto - Mobile Veterinarians      Veterinarian
# 11                               Bayside Veterinarian      Veterinarian
# 12                                  Port Veterinarian  Airport Terminal
# 13                                   MVA Veterinarian      Veterinarian
# 14                        Carnegie Hill Veterinarians      Veterinarian
# 15                                     Call Ahead Vet      Veterinarian
# 16                      Heights Veterinary Associates      Veterinarian
# 17                     Animal Hospital of Morris Park      Veterinarian
# 18                      Windsor Terrace Veterinarians      Veterinarian
# 19                      Dr. Brenda King, Veterinarian      Veterinarian
# 20                             Bayside Veterinary Ctr       Pet Service
# 21                   Dongan Hills Veterinary Practice      Veterinarian
# 22               Catnip & Carrots Veterinary Hospital      Veterinarian
#
#                                      address  cc            city  \
# 0                       32-41 Steinway St #R  US         Astoria
# 1                              340 E 11th St  US        New York
# 2                                        NaN  US  Middle Village
# 3                             27-15 24th Ave  US         Astoria
# 4                      42-06 Steinway Street  US         Astoria
# 5                       170 East 66th Street  US        New York
# 6                              220 West ZEnd  US        New York
# 7                              170 W 96th St  US        New York
# 8                                639 4th Ave  US        Brooklyn
# 9                              204 E 76th St  US        New York
# 10                              1461 1st Ave  US        New York
# 11                                 Bell Blvd  US         Bayside
# 12  230-59 International Airport Center Blvd  US         Jamaica
# 13                                       NaN  US        Brooklyn
# 14                              1707 3rd Ave  US        New York
# 15                               654 5th Ave  US        Brooklyn
# 16                 3402 John F. Kennedy Blvd  US     Jersey City
# 17                   1135 Morris Park Avenue  US           Bronx
# 18                           1252 Prospect A  US        Brooklyn
# 19                               2 Forest St  US       Montclair
# 20                           204-18 46th Ave  US         Bayside
# 21                      289 Dongan Hills Ave  US   Staten Island
# 22                         2056 Jericho Tpke  US   New Hyde Park
#
#           country                crossStreet  distance  \
# 0   United States                        NaN      3300
# 1   United States         btwn 1st & 2nd Ave      4158
# 2   United States                        NaN      5526
# 3   United States                        NaN      5022
# 4   United States                        NaN      3286
# 5   United States  3rd ave and Lexington Ave      4446
# 6   United States                   Broadway      6707
# 7   United States                  Amsterdam      7621
# 8   United States                       19th      8960
# 9   United States                        NaN      5000
# 10  United States                        NaN      4744
# 11  United States                        NaN     13939
# 12  United States                        NaN     17527
# 13  United States                        NaN     15466
# 14  United States                      E96th      6161
# 15  United States       19th and 20th Street      8988
# 16  United States                        NaN     10334
# 17  United States          Williamsbridge Rd     15060
# 18  United States                   Reeve Pl      9347
# 19  United States           Glenridge Avenue     23738
# 20  United States                        NaN     13596
# 21  United States                        NaN     21042
# 22  United States                at Brian St     22162
#
#                                      formattedAddress  \
# 0   [32-41 Steinway St #R, Astoria, NY 11103, Unit...
# 1   [340 E 11th St (btwn 1st & 2nd Ave), New York,...
# 2           [Middle Village, NY 11379, United States]
# 3   [27-15 24th Ave, Astoria, NY 11102, United Sta...
# 4   [42-06 Steinway Street, Astoria, NY, United St...
# 5   [170 East 66th Street (3rd ave and Lexington A...
# 6   [220 West ZEnd (Broadway), New York, NY 10023,...
# 7   [170 W 96th St (Amsterdam), New York, NY 10025...
# 8   [639 4th Ave (19th), Brooklyn, NY 11232, Unite...
# 9   [204 E 76th St, New York, NY 10021, United Sta...
# 10  [1461 1st Ave, New York, NY 10075, United States]
# 11      [Bell Blvd, Bayside, NY 11361, United States]
# 12  [230-59 International Airport Center Blvd, Jam...
# 13                [Brooklyn, NY 11223, United States]
# 14  [1707 3rd Ave (E96th), New York, NY 10128, Uni...
# 15  [654 5th Ave (19th and 20th Street), Brooklyn,...
# 16  [3402 John F. Kennedy Blvd, Jersey City, NJ 07...
# 17  [1135 Morris Park Avenue (Williamsbridge Rd), ...
# 18  [1252 Prospect A (Reeve Pl), Brooklyn, NY, Uni...
# 19  [2 Forest St (Glenridge Avenue), Montclair, NJ...
# 20  [204-18 46th Ave, Bayside, NY 11361, United St...
# 21  [289 Dongan Hills Ave, Staten Island, NY 10305...
# 22  [2056 Jericho Tpke (at Brian St), New Hyde Par...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lng': -73.91970744124593, 'lat': 40.7578259...  40.757826 -73.919707
# 1   [{'lng': -73.9845220240651, 'lat': 40.72961372...  40.729614 -73.984522
# 2   [{'lng': -73.87394851383898, 'lat': 40.7130894...  40.713089 -73.873949
# 3   [{'lng': -73.91728041463668, 'lat': 40.7736239...  40.773624 -73.917280
# 4   [{'lng': -73.91963522518799, 'lat': 40.7576572...  40.757657 -73.919635
# 5   [{'lng': -73.96614074707031, 'lat': 40.7629749...  40.762975 -73.966141
# 6   [{'lng': -73.98263275921593, 'lat': 40.7790004...  40.779000 -73.982633
# 7   [{'lng': -73.96991198344747, 'lat': 40.7938439...  40.793844 -73.969912
# 8   [{'lng': -73.9944164320893, 'lat': 40.66377523...  40.663775 -73.994416
# 9   [{'lng': -73.958382, 'lat': 40.771973, 'label'...  40.771973 -73.958382
# 10  [{'lng': -73.9543049, 'lat': 40.77070601, 'lab...  40.770706 -73.954305
# 11  [{'lng': -73.77725200326664, 'lat': 40.7674132...  40.767413 -73.777252
# 12  [{'lng': -73.756419, 'lat': 40.65057, 'label':...  40.650570 -73.756419
# 13  [{'lng': -73.97725509387166, 'lat': 40.5953765...  40.595377 -73.977255
# 14  [{'lng': -73.94932555041507, 'lat': 40.7849210...  40.784921 -73.949326
# 15  [{'lng': -73.99244072805992, 'lat': 40.6625012...  40.662501 -73.992441
# 16  [{'lng': -74.0554712, 'lat': 40.74849486, 'lab...  40.748495 -74.055471
# 17  [{'lng': -73.85180468158171, 'lat': 40.8502447...  40.850245 -73.851805
# 18  [{'lng': -73.97616, 'lat': 40.65257863, 'label...  40.652579 -73.976160
# 19  [{'lng': -74.20296154417177, 'lat': 40.7966273...  40.796627 -74.202962
# 20  [{'lng': -73.77748755540115, 'lat': 40.7557694...  40.755769 -73.777488
# 21  [{'lng': -74.09329178956217, 'lat': 40.5844735...  40.584474 -74.093292
# 22  [{'lng': -73.67260024049297, 'lat': 40.7360854...  40.736085 -73.672600
#
#    postalCode state                        id
# 0       11103    NY  4b91517df964a520b3b233e3
# 1       10003    NY  4c3c83e04bc9a5932fbcd271
# 2       11379    NY  4cb86d6ea33bb1f713eb80fd
# 3       11102    NY  56324b4d498eb5f26f97403d
# 4         NaN    NY  55043316498e6198e7f41f46
# 5       10065    NY  54e1f61c498eee7bd0893ee5
# 6       10023    NY  4b8abb03f964a520107d32e3
# 7       10025    NY  4e2af41da809f1b1640a346b
# 8       11232    NY  4d948000af67370459027d09
# 9       10021    NY  4bc08ba9920eb713e10b192c
# 10      10075    NY  5ab6c4ac9411f2343fa8168f
# 11      11361    NY  4ff0bd10e4b0581584aa40b2
# 12      11413    NY  4dd29efb1f6ef5f6ccd90498
# 13      11223    NY  50c360bbe4b0e0fa34731cf9
# 14      10128    NY  53c54703498efa2cc64107e7
# 15      11215    NY  4ea88fe46c253859bb057061
# 16      07307    NJ  502198cfe4b0f661aadec0ef
# 17      10461    NY  4ca63f8ef47ea143bec25e21
# 18        NaN    NY  4b2112e9f964a5209e3624e3
# 19      07042    NJ  4f9aac33e4b0d296c63372d0
# 20      11361    NY  4ccc4d7b2dc43704f948c608
# 21      10305    NY  4c34d4594308b7136589c430
# 22      11040    NY  4c1659707f7f2d7f0cd3e368

# %%
#lets see what areas are in the data frame
venues_filter.city.unique()
# Out:
# array(['Astoria', 'New York', 'Middle Village', 'Brooklyn', 'Bayside',
#        'Jamaica', 'Jersey City', 'Bronx', 'Montclair', 'Staten Island',
#        'New Hyde Park'], dtype=object)

# %%
#we can see that in our list there are some wrong venues (for example "Port Veterinarian Airport Terminal") - we need to get rid of them!
venues_filter = venues_filter.drop(venues_filter[venues_filter.categories !='Veterinarian'].index)

#lets also drop venues from the outside of New York State
venues_filter = venues_filter.drop(venues_filter[venues_filter.state !='NY'].index)

#now lets get rid of clinics which do not belong to New York City - knowing the fact that there are only Bronx, Brooklyn, Manhattan, New York, Queens and Staten Island are the right cities for NYC.
venues_filter = venues_filter.loc[(venues_filter['city']=='Bronx')|(venues_filter['city']=='Brooklyn')|(venues_filter['city']=='Manhattan')|(venues_filter['city']=='New York')|(venues_filter['city']=='Queens')|(venues_filter['city']=='Staten Island')]

#lets see the "clean" result
venues_filter
# Out:
#                                                  name    categories  \
# 1                            The Village Veterinarian  Veterinarian
# 5   Dr. Cindy Bressler House Call Veterinarian NYC...  Veterinarian
# 6                                   City Veterinarian  Veterinarian
# 7                                 Symphony Vet Center  Veterinarian
# 8                        Park Slope Veterinary Center  Veterinarian
# 9                            Lenox Hill Veterinarians  Veterinarian
# 10                   VetPronto - Mobile Veterinarians  Veterinarian
# 13                                   MVA Veterinarian  Veterinarian
# 14                        Carnegie Hill Veterinarians  Veterinarian
# 15                                     Call Ahead Vet  Veterinarian
# 17                     Animal Hospital of Morris Park  Veterinarian
# 18                      Windsor Terrace Veterinarians  Veterinarian
# 21                   Dongan Hills Veterinary Practice  Veterinarian
#
#                     address  cc           city        country  \
# 1             340 E 11th St  US       New York  United States
# 5      170 East 66th Street  US       New York  United States
# 6             220 West ZEnd  US       New York  United States
# 7             170 W 96th St  US       New York  United States
# 8               639 4th Ave  US       Brooklyn  United States
# 9             204 E 76th St  US       New York  United States
# 10             1461 1st Ave  US       New York  United States
# 13                      NaN  US       Brooklyn  United States
# 14             1707 3rd Ave  US       New York  United States
# 15              654 5th Ave  US       Brooklyn  United States
# 17  1135 Morris Park Avenue  US          Bronx  United States
# 18          1252 Prospect A  US       Brooklyn  United States
# 21     289 Dongan Hills Ave  US  Staten Island  United States
#
#                   crossStreet  distance  \
# 1          btwn 1st & 2nd Ave      4158
# 5   3rd ave and Lexington Ave      4446
# 6                    Broadway      6707
# 7                   Amsterdam      7621
# 8                        19th      8960
# 9                         NaN      5000
# 10                        NaN      4744
# 13                        NaN     15466
# 14                      E96th      6161
# 15       19th and 20th Street      8988
# 17          Williamsbridge Rd     15060
# 18                   Reeve Pl      9347
# 21                        NaN     21042
#
#                                      formattedAddress  \
# 1   [340 E 11th St (btwn 1st & 2nd Ave), New York,...
# 5   [170 East 66th Street (3rd ave and Lexington A...
# 6   [220 West ZEnd (Broadway), New York, NY 10023,...
# 7   [170 W 96th St (Amsterdam), New York, NY 10025...
# 8   [639 4th Ave (19th), Brooklyn, NY 11232, Unite...
# 9   [204 E 76th St, New York, NY 10021, United Sta...
# 10  [1461 1st Ave, New York, NY 10075, United States]
# 13                [Brooklyn, NY 11223, United States]
# 14  [1707 3rd Ave (E96th), New York, NY 10128, Uni...
# 15  [654 5th Ave (19th and 20th Street), Brooklyn,...
# 17  [1135 Morris Park Avenue (Williamsbridge Rd), ...
# 18  [1252 Prospect A (Reeve Pl), Brooklyn, NY, Uni...
# 21  [289 Dongan Hills Ave, Staten Island, NY 10305...
#
#                                        labeledLatLngs        lat        lng  \
# 1   [{'lng': -73.9845220240651, 'lat': 40.72961372...  40.729614 -73.984522
# 5   [{'lng': -73.96614074707031, 'lat': 40.7629749...  40.762975 -73.966141
# 6   [{'lng': -73.98263275921593, 'lat': 40.7790004...  40.779000 -73.982633
# 7   [{'lng': -73.96991198344747, 'lat': 40.7938439...  40.793844 -73.969912
# 8   [{'lng': -73.9944164320893, 'lat': 40.66377523...  40.663775 -73.994416
# 9   [{'lng': -73.958382, 'lat': 40.771973, 'label'...  40.771973 -73.958382
# 10  [{'lng': -73.9543049, 'lat': 40.77070601, 'lab...  40.770706 -73.954305
# 13  [{'lng': -73.97725509387166, 'lat': 40.5953765...  40.595377 -73.977255
# 14  [{'lng': -73.94932555041507, 'lat': 40.7849210...  40.784921 -73.949326
# 15  [{'lng': -73.99244072805992, 'lat': 40.6625012...  40.662501 -73.992441
# 17  [{'lng': -73.85180468158171, 'lat': 40.8502447...  40.850245 -73.851805
# 18  [{'lng': -73.97616, 'lat': 40.65257863, 'label...  40.652579 -73.976160
# 21  [{'lng': -74.09329178956217, 'lat': 40.5844735...  40.584474 -74.093292
#
#    postalCode state                        id
# 1       10003    NY  4c3c83e04bc9a5932fbcd271
# 5       10065    NY  54e1f61c498eee7bd0893ee5
# 6       10023    NY  4b8abb03f964a520107d32e3
# 7       10025    NY  4e2af41da809f1b1640a346b
# 8       11232    NY  4d948000af67370459027d09
# 9       10021    NY  4bc08ba9920eb713e10b192c
# 10      10075    NY  5ab6c4ac9411f2343fa8168f
# 13      11223    NY  50c360bbe4b0e0fa34731cf9
# 14      10128    NY  53c54703498efa2cc64107e7
# 15      11215    NY  4ea88fe46c253859bb057061
# 17      10461    NY  4ca63f8ef47ea143bec25e21
# 18        NaN    NY  4b2112e9f964a5209e3624e3
# 21      10305    NY  4c34d4594308b7136589c430

# %%
#lets group and fetch only the necessary info
venues_filter= venues_filter[['name','categories','address','city','lat','lng','id']]

#reset indexes
venues_filter = venues_filter.reset_index(drop=True)

#show result
venues_filter
# Out:
#                                                  name    categories  \
# 0                            The Village Veterinarian  Veterinarian
# 1   Dr. Cindy Bressler House Call Veterinarian NYC...  Veterinarian
# 2                                   City Veterinarian  Veterinarian
# 3                                 Symphony Vet Center  Veterinarian
# 4                        Park Slope Veterinary Center  Veterinarian
# 5                            Lenox Hill Veterinarians  Veterinarian
# 6                    VetPronto - Mobile Veterinarians  Veterinarian
# 7                                    MVA Veterinarian  Veterinarian
# 8                         Carnegie Hill Veterinarians  Veterinarian
# 9                                      Call Ahead Vet  Veterinarian
# 10                     Animal Hospital of Morris Park  Veterinarian
# 11                      Windsor Terrace Veterinarians  Veterinarian
# 12                   Dongan Hills Veterinary Practice  Veterinarian
#
#                     address           city        lat        lng  \
# 0             340 E 11th St       New York  40.729614 -73.984522
# 1      170 East 66th Street       New York  40.762975 -73.966141
# 2             220 West ZEnd       New York  40.779000 -73.982633
# 3             170 W 96th St       New York  40.793844 -73.969912
# 4               639 4th Ave       Brooklyn  40.663775 -73.994416
# 5             204 E 76th St       New York  40.771973 -73.958382
# 6              1461 1st Ave       New York  40.770706 -73.954305
# 7                       NaN       Brooklyn  40.595377 -73.977255
# 8              1707 3rd Ave       New York  40.784921 -73.949326
# 9               654 5th Ave       Brooklyn  40.662501 -73.992441
# 10  1135 Morris Park Avenue          Bronx  40.850245 -73.851805
# 11          1252 Prospect A       Brooklyn  40.652579 -73.976160
# 12     289 Dongan Hills Ave  Staten Island  40.584474 -74.093292
#
#                           id
# 0   4c3c83e04bc9a5932fbcd271
# 1   54e1f61c498eee7bd0893ee5
# 2   4b8abb03f964a520107d32e3
# 3   4e2af41da809f1b1640a346b
# 4   4d948000af67370459027d09
# 5   4bc08ba9920eb713e10b192c
# 6   5ab6c4ac9411f2343fa8168f
# 7   50c360bbe4b0e0fa34731cf9
# 8   53c54703498efa2cc64107e7
# 9   4ea88fe46c253859bb057061
# 10  4ca63f8ef47ea143bec25e21
# 11  4b2112e9f964a5209e3624e3
# 12  4c34d4594308b7136589c430

# %% [markdown]
# <h2>So, now I have all the neccessary info for my research!</h2>
